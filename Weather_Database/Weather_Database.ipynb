# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cd6ad5abd693> in <module>
#       3 cities = []
#       4 # Identify the nearest city for each latitude and longitude combination.
# ----> 5 for coordinate in coordinates:
#       6     city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
#       7
#
# NameError: name 'coordinates' is not defined

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | vestmannaeyjar
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | pidhorodna
# Processing Record 6 of Set 1 | belmonte
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | buala
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | kahului
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | mastic beach
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | roald
# Processing Record 16 of Set 1 | bengkulu
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | sur
# Processing Record 19 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | beyneu
# Processing Record 22 of Set 1 | padang
# Processing Record 23 of Set 1 | naze
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | kumluca
# Processing Record 27 of Set 1 | barrow
# Processing Record 28 of Set 1 | zhigansk
# Processing Record 29 of Set 1 | vaini
# Processing Record 30 of Set 1 | korla
# Processing Record 31 of Set 1 | isangel
# Processing Record 32 of Set 1 | raudeberg
# Processing Record 33 of Set 1 | labrea
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | sochaczew
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | plettenberg bay
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | haines junction
# Processing Record 41 of Set 1 | sao joao da barra
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | watsa
# Processing Record 44 of Set 1 | glencoe
# Processing Record 45 of Set 1 | loa janan
# Processing Record 46 of Set 1 | juneau
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | ivanovka
# Processing Record 49 of Set 1 | gizo
# Processing Record 50 of Set 1 | laguna
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | caluquembe
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 6 of Set 2 | baruun-urt
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | progreso
# Processing Record 9 of Set 2 | ballina
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | shimoda
# Processing Record 12 of Set 2 | aksu
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | beringovskiy
# Processing Record 15 of Set 2 | dingle
# Processing Record 16 of Set 2 | norman wells
# Processing Record 17 of Set 2 | vostok
# Processing Record 18 of Set 2 | zapolyarnyy
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | launceston
# Processing Record 25 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 26 of Set 2 | port lincoln
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | vila franca do campo
# Processing Record 29 of Set 2 | alugan
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | santa fe
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | oksfjord
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | ambon
# Processing Record 42 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | whitefish
# Processing Record 44 of Set 2 | mosquera
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | novoraychikhinsk
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | bambanglipuro
# Processing Record 50 of Set 2 | mataura
# Processing Record 1 of Set 3 | cherskiy
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | gravelbourg
# Processing Record 5 of Set 3 | mopipi
# Processing Record 6 of Set 3 | port hedland
# Processing Record 7 of Set 3 | cockburn town
# Processing Record 8 of Set 3 | saravena
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | tacarigua
# Processing Record 11 of Set 3 | antofagasta
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | kaohsiung
# Processing Record 14 of Set 3 | luderitz
# Processing Record 15 of Set 3 | college
# Processing Record 16 of Set 3 | puerto madryn
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | poum
# Processing Record 19 of Set 3 | kamenka
# Processing Record 20 of Set 3 | bathsheba
# Processing Record 21 of Set 3 | luoyang
# Processing Record 22 of Set 3 | westport
# Processing Record 23 of Set 3 | pangnirtung
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | high level
# Processing Record 27 of Set 3 | tiznit
# Processing Record 28 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 3 | muros
# Processing Record 30 of Set 3 | castro
# Processing Record 31 of Set 3 | gemena
# Processing Record 32 of Set 3 | trelew
# Processing Record 33 of Set 3 | jiaocheng
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | kallaste
# Processing Record 37 of Set 3 | pevek
# Processing Record 38 of Set 3 | bafata
# Processing Record 39 of Set 3 | novikovo
# Processing Record 40 of Set 3 | tigzirt
# Processing Record 41 of Set 3 | igboho
# Processing Record 42 of Set 3 | asfi
# Processing Record 43 of Set 3 | kutum
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 3 | yunyang
# Processing Record 47 of Set 3 | lata
# Processing Record 48 of Set 3 | goryachiy klyuch
# Processing Record 49 of Set 3 | chimbote
# Processing Record 50 of Set 3 | portland
# Processing Record 1 of Set 4 | cabo san lucas
# Processing Record 2 of Set 4 | russell
# Processing Record 3 of Set 4 | henties bay
# Processing Record 4 of Set 4 | reconquista
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | la ronge
# Processing Record 7 of Set 4 | ushirombo
# Processing Record 8 of Set 4 | bafilo
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | kununurra
# Processing Record 12 of Set 4 | lamu
# Processing Record 13 of Set 4 | joshimath
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | chokurdakh
# Processing Record 18 of Set 4 | dobson
# Processing Record 19 of Set 4 | altamira
# Processing Record 20 of Set 4 | ilulissat
# Processing Record 21 of Set 4 | martapura
# Processing Record 22 of Set 4 | birao
# Processing Record 23 of Set 4 | taitung
# Processing Record 24 of Set 4 | zelenogradsk
# Processing Record 25 of Set 4 | coolum beach
# Processing Record 26 of Set 4 | whitehorse
# Processing Record 27 of Set 4 | winchester
# Processing Record 28 of Set 4 | senneterre
# Processing Record 29 of Set 4 | ponta do sol
# Processing Record 30 of Set 4 | chau doc
# Processing Record 31 of Set 4 | dosso
# Processing Record 32 of Set 4 | saint anthony
# Processing Record 33 of Set 4 | mezen
# Processing Record 34 of Set 4 | panama city
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | cairns
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | kodiak
# Processing Record 39 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | joensuu
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | severodvinsk
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | port keats
# Processing Record 46 of Set 4 | paita
# Processing Record 47 of Set 4 | faya
# Processing Record 48 of Set 4 | teahupoo
# Processing Record 49 of Set 4 | yar-sale
# Processing Record 50 of Set 4 | jibuti
# Processing Record 1 of Set 5 | labuhan
# Processing Record 2 of Set 5 | dabat
# Processing Record 3 of Set 5 | ozinki
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | beloha
# Processing Record 9 of Set 5 | zholymbet
# Processing Record 10 of Set 5 | bambous virieux
# Processing Record 11 of Set 5 | ranong
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | north bend
# Processing Record 14 of Set 5 | oga
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | port alfred
# Processing Record 17 of Set 5 | luena
# Processing Record 18 of Set 5 | tshikapa
# Processing Record 19 of Set 5 | paducah
# Processing Record 20 of Set 5 | vaitape
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | hinesville
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | kangaatsiaq
# Processing Record 26 of Set 5 | hilo
# Processing Record 27 of Set 5 | tondano
# Processing Record 28 of Set 5 | kaeo
# Processing Record 29 of Set 5 | clyde river
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | tarrafal
# Processing Record 32 of Set 5 | lavrentiya
# Processing Record 33 of Set 5 | gold coast
# Processing Record 34 of Set 5 | impfondo
# Processing Record 35 of Set 5 | muisne
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | sitka
# Processing Record 38 of Set 5 | bina-etawa
# City not found. Skipping...
# Processing Record 39 of Set 5 | mogadishu
# Processing Record 40 of Set 5 | phulera
# Processing Record 41 of Set 5 | selizharovo
# Processing Record 42 of Set 5 | yarim
# Processing Record 43 of Set 5 | evensk
# Processing Record 44 of Set 5 | dibaya
# City not found. Skipping...
# Processing Record 45 of Set 5 | pedernales
# Processing Record 46 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 5 | dikson
# Processing Record 48 of Set 5 | baghdad
# Processing Record 49 of Set 5 | aldan
# Processing Record 50 of Set 5 | taklisah
# Processing Record 1 of Set 6 | at-bashi
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | saint-francois
# Processing Record 4 of Set 6 | cacequi
# Processing Record 5 of Set 6 | limbazi
# Processing Record 6 of Set 6 | georgetown
# Processing Record 7 of Set 6 | kambove
# Processing Record 8 of Set 6 | east london
# Processing Record 9 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 6 | port hardy
# Processing Record 11 of Set 6 | saint-ambroise
# Processing Record 12 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 6 | srednekolymsk
# Processing Record 14 of Set 6 | luang prabang
# Processing Record 15 of Set 6 | maymanak
# City not found. Skipping...
# Processing Record 16 of Set 6 | hambantota
# Processing Record 17 of Set 6 | hualmay
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | ust-kuyga
# Processing Record 21 of Set 6 | acarau
# Processing Record 22 of Set 6 | lompoc
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | ahipara
# Processing Record 25 of Set 6 | weiser
# Processing Record 26 of Set 6 | urucara
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | conakry
# Processing Record 30 of Set 6 | san angelo
# Processing Record 31 of Set 6 | santa barbara
# Processing Record 32 of Set 6 | vao
# Processing Record 33 of Set 6 | podgornoye
# Processing Record 34 of Set 6 | bonavista
# Processing Record 35 of Set 6 | nelson bay
# Processing Record 36 of Set 6 | geraldton
# Processing Record 37 of Set 6 | san quintin
# Processing Record 38 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 6 | vila velha
# Processing Record 41 of Set 6 | palmares do sul
# Processing Record 42 of Set 6 | severo-kurilsk
# Processing Record 43 of Set 6 | atar
# Processing Record 44 of Set 6 | neiafu
# Processing Record 45 of Set 6 | namibe
# Processing Record 46 of Set 6 | qaanaaq
# Processing Record 47 of Set 6 | ahvaz
# Processing Record 48 of Set 6 | kamaishi
# Processing Record 49 of Set 6 | pervomayskiy
# Processing Record 50 of Set 6 | susanville
# Processing Record 1 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 7 | oranjemund
# Processing Record 3 of Set 7 | tuatapere
# Processing Record 4 of Set 7 | shenjiamen
# Processing Record 5 of Set 7 | rimavska sobota
# Processing Record 6 of Set 7 | gatton
# Processing Record 7 of Set 7 | san borja
# Processing Record 8 of Set 7 | caravelas
# Processing Record 9 of Set 7 | toora-khem
# Processing Record 10 of Set 7 | kabalo
# Processing Record 11 of Set 7 | berdyuzhye
# City not found. Skipping...
# Processing Record 12 of Set 7 | port elizabeth
# Processing Record 13 of Set 7 | ravar
# Processing Record 14 of Set 7 | puro
# Processing Record 15 of Set 7 | lebu
# Processing Record 16 of Set 7 | port-gentil
# Processing Record 17 of Set 7 | san cristobal
# Processing Record 18 of Set 7 | san isidro
# Processing Record 19 of Set 7 | mehamn
# Processing Record 20 of Set 7 | vilyuysk
# Processing Record 21 of Set 7 | erzin
# Processing Record 22 of Set 7 | provideniya
# Processing Record 23 of Set 7 | mopti
# Processing Record 24 of Set 7 | mbanza-ngungu
# Processing Record 25 of Set 7 | muravlenko
# Processing Record 26 of Set 7 | granja
# Processing Record 27 of Set 7 | ulaanbaatar
# Processing Record 28 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 7 | kolyvan
# Processing Record 30 of Set 7 | santa quiteria
# Processing Record 31 of Set 7 | tucuman
# Processing Record 32 of Set 7 | rio gallegos
# Processing Record 33 of Set 7 | hun
# Processing Record 34 of Set 7 | nioro
# Processing Record 35 of Set 7 | mount isa
# Processing Record 36 of Set 7 | lorengau
# Processing Record 37 of Set 7 | churapcha
# Processing Record 38 of Set 7 | phalodi
# Processing Record 39 of Set 7 | udarnyy
# Processing Record 40 of Set 7 | dois vizinhos
# Processing Record 41 of Set 7 | komsomolskiy
# Processing Record 42 of Set 7 | montepuez
# Processing Record 43 of Set 7 | pimentel
# Processing Record 44 of Set 7 | chuy
# Processing Record 45 of Set 7 | vanavara
# Processing Record 46 of Set 7 | bolpur
# Processing Record 47 of Set 7 | wad madani
# Processing Record 48 of Set 7 | hauterive
# Processing Record 49 of Set 7 | basco
# Processing Record 50 of Set 7 | sinnamary
# Processing Record 1 of Set 8 | sambava
# Processing Record 2 of Set 8 | bereznik
# Processing Record 3 of Set 8 | vangaindrano
# Processing Record 4 of Set 8 | wagar
# Processing Record 5 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 8 | kitui
# Processing Record 7 of Set 8 | armeria
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | kuusamo
# Processing Record 10 of Set 8 | boende
# Processing Record 11 of Set 8 | yerofey pavlovich
# Processing Record 12 of Set 8 | hwange
# Processing Record 13 of Set 8 | batsfjord
# Processing Record 14 of Set 8 | berbera
# Processing Record 15 of Set 8 | gushikawa
# Processing Record 16 of Set 8 | karratha
# Processing Record 17 of Set 8 | umm lajj
# Processing Record 18 of Set 8 | socorro
# Processing Record 19 of Set 8 | timra
# Processing Record 20 of Set 8 | guaymas
# Processing Record 21 of Set 8 | cayenne
# Processing Record 22 of Set 8 | vorukh
# Processing Record 23 of Set 8 | baiao
# Processing Record 24 of Set 8 | knyaze-volkonskoye
# Processing Record 25 of Set 8 | esperance
# Processing Record 26 of Set 8 | hengshui
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | ketchikan
# Processing Record 29 of Set 8 | pacific grove
# Processing Record 30 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 8 | kudahuvadhoo
# Processing Record 32 of Set 8 | dullewala
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | humaita
# Processing Record 35 of Set 8 | yaan
# Processing Record 36 of Set 8 | jiuquan
# Processing Record 37 of Set 8 | tagbac
# Processing Record 38 of Set 8 | victoria
# Processing Record 39 of Set 8 | pozo colorado
# Processing Record 40 of Set 8 | orocue
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | nanortalik
# Processing Record 43 of Set 8 | waddan
# Processing Record 44 of Set 8 | tanakpur
# Processing Record 45 of Set 8 | belfast
# Processing Record 46 of Set 8 | fortuna foothills
# Processing Record 47 of Set 8 | hare bay
# Processing Record 48 of Set 8 | brae
# Processing Record 49 of Set 8 | montpelier
# Processing Record 50 of Set 8 | lokosovo
# Processing Record 1 of Set 9 | oistins
# Processing Record 2 of Set 9 | kagalnitskaya
# Processing Record 3 of Set 9 | fukue
# Processing Record 4 of Set 9 | beawar
# Processing Record 5 of Set 9 | touros
# Processing Record 6 of Set 9 | lincoln
# Processing Record 7 of Set 9 | abu dhabi
# Processing Record 8 of Set 9 | kiunga
# Processing Record 9 of Set 9 | canon city
# Processing Record 10 of Set 9 | bilma
# Processing Record 11 of Set 9 | orsha
# Processing Record 12 of Set 9 | mao
# Processing Record 13 of Set 9 | talnakh
# Processing Record 14 of Set 9 | weligama
# Processing Record 15 of Set 9 | askarovo
# Processing Record 16 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 17 of Set 9 | pangody
# Processing Record 18 of Set 9 | puerto escondido
# Processing Record 19 of Set 9 | hirara
# Processing Record 20 of Set 9 | taltal
# Processing Record 21 of Set 9 | narsaq
# Processing Record 22 of Set 9 | svetlogorsk
# Processing Record 23 of Set 9 | wasilla
# Processing Record 24 of Set 9 | klaksvik
# Processing Record 25 of Set 9 | musoma
# Processing Record 26 of Set 9 | nicoya
# Processing Record 27 of Set 9 | faanui
# Processing Record 28 of Set 9 | makakilo city
# Processing Record 29 of Set 9 | krasnoselkup
# Processing Record 30 of Set 9 | adrar
# Processing Record 31 of Set 9 | te anau
# Processing Record 32 of Set 9 | coquimbo
# Processing Record 33 of Set 9 | pokosnoye
# Processing Record 34 of Set 9 | ygatimi
# Processing Record 35 of Set 9 | marrakesh
# Processing Record 36 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 37 of Set 9 | horqueta
# Processing Record 38 of Set 9 | flinders
# Processing Record 39 of Set 9 | xiamen
# Processing Record 40 of Set 9 | tirumullaivasal
# Processing Record 41 of Set 9 | russellville
# Processing Record 42 of Set 9 | najran
# Processing Record 43 of Set 9 | serro
# Processing Record 44 of Set 9 | gunjur
# Processing Record 45 of Set 9 | rock springs
# Processing Record 46 of Set 9 | andilamena
# Processing Record 47 of Set 9 | beckley
# Processing Record 48 of Set 9 | altay
# Processing Record 49 of Set 9 | port hueneme
# Processing Record 50 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 10 | atyrau
# Processing Record 2 of Set 10 | saint-georges
# Processing Record 3 of Set 10 | nouadhibou
# Processing Record 4 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 10 | kurumkan
# Processing Record 6 of Set 10 | suileng
# Processing Record 7 of Set 10 | comodoro rivadavia
# Processing Record 8 of Set 10 | cheremnoye
# Processing Record 9 of Set 10 | tateyama
# Processing Record 10 of Set 10 | kiama
# Processing Record 11 of Set 10 | galdar
# Processing Record 12 of Set 10 | arapongas
# Processing Record 13 of Set 10 | conchas
# Processing Record 14 of Set 10 | norrtalje
# Processing Record 15 of Set 10 | pemba
# Processing Record 16 of Set 10 | lakatoro
# Processing Record 17 of Set 10 | margate
# Processing Record 18 of Set 10 | athabasca
# Processing Record 19 of Set 10 | rovaniemi
# Processing Record 20 of Set 10 | bridgeton
# Processing Record 21 of Set 10 | honiara
# Processing Record 22 of Set 10 | murupara
# Processing Record 23 of Set 10 | winslow
# Processing Record 24 of Set 10 | shingu
# Processing Record 25 of Set 10 | campo verde
# Processing Record 26 of Set 10 | hami
# Processing Record 27 of Set 10 | hervey bay
# Processing Record 28 of Set 10 | khandbari
# Processing Record 29 of Set 10 | axim
# Processing Record 30 of Set 10 | wageningen
# Processing Record 31 of Set 10 | gotsu
# Processing Record 32 of Set 10 | kpandae
# Processing Record 33 of Set 10 | vincennes
# Processing Record 34 of Set 10 | salalah
# Processing Record 35 of Set 10 | nha trang
# Processing Record 36 of Set 10 | cabano
# Processing Record 37 of Set 10 | chimoio
# Processing Record 38 of Set 10 | caborca
# Processing Record 39 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 10 | belyy yar
# Processing Record 41 of Set 10 | kavaratti
# Processing Record 42 of Set 10 | phulji
# Processing Record 43 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 10 | itoman
# Processing Record 45 of Set 10 | maniitsoq
# Processing Record 46 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 10 | darab
# Processing Record 48 of Set 10 | codrington
# Processing Record 49 of Set 10 | oeiras
# Processing Record 50 of Set 10 | celestun
# Processing Record 1 of Set 11 | xacmaz
# Processing Record 2 of Set 11 | ouegoa
# Processing Record 3 of Set 11 | pampas
# Processing Record 4 of Set 11 | lodja
# Processing Record 5 of Set 11 | gornopravdinsk
# Processing Record 6 of Set 11 | freeport
# Processing Record 7 of Set 11 | chabahar
# Processing Record 8 of Set 11 | csengele
# Processing Record 9 of Set 11 | ocos
# Processing Record 10 of Set 11 | izazi
# Processing Record 11 of Set 11 | wick
# Processing Record 12 of Set 11 | khani
# Processing Record 13 of Set 11 | havelock
# Processing Record 14 of Set 11 | grabouw
# Processing Record 15 of Set 11 | santa maria
# Processing Record 16 of Set 11 | palana
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | ambanja
# Processing Record 19 of Set 11 | mumford
# Processing Record 20 of Set 11 | jacareacanga
# Processing Record 21 of Set 11 | verkhnyaya inta
# Processing Record 22 of Set 11 | jesus carranza
# Processing Record 23 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 11 | kabanjahe
# Processing Record 25 of Set 11 | luna
# Processing Record 26 of Set 11 | owerri
# Processing Record 27 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 28 of Set 11 | plouzane
# Processing Record 29 of Set 11 | sakakah
# Processing Record 30 of Set 11 | okha
# Processing Record 31 of Set 11 | praya
# Processing Record 32 of Set 11 | luorong
# Processing Record 33 of Set 11 | gilleleje
# Processing Record 34 of Set 11 | floro
# Processing Record 35 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 11 | manhattan
# Processing Record 37 of Set 11 | pacifica
# Processing Record 38 of Set 11 | prata
# Processing Record 39 of Set 11 | shirgaon
# Processing Record 40 of Set 11 | okhotsk
# Processing Record 41 of Set 11 | campos do jordao
# Processing Record 42 of Set 11 | baykit
# Processing Record 43 of Set 11 | san ignacio
# Processing Record 44 of Set 11 | san luis
# Processing Record 45 of Set 11 | kieta
# Processing Record 46 of Set 11 | suez
# Processing Record 47 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 48 of Set 11 | dezhou
# Processing Record 49 of Set 11 | anadyr
# Processing Record 50 of Set 11 | nanakuli
# Processing Record 1 of Set 12 | riyadh
# Processing Record 2 of Set 12 | coruripe
# Processing Record 3 of Set 12 | manono
# Processing Record 4 of Set 12 | koumac
# Processing Record 5 of Set 12 | andenes
# Processing Record 6 of Set 12 | mayor pablo lagerenza
# Processing Record 7 of Set 12 | karuzi
# Processing Record 8 of Set 12 | ayr
# Processing Record 9 of Set 12 | souris
# Processing Record 10 of Set 12 | noumea
# Processing Record 11 of Set 12 | tautira
# Processing Record 12 of Set 12 | cabedelo
# Processing Record 13 of Set 12 | bardsir
# Processing Record 14 of Set 12 | itarema
# Processing Record 15 of Set 12 | alta floresta
# Processing Record 16 of Set 12 | jishou
# Processing Record 17 of Set 12 | varberg
# Processing Record 18 of Set 12 | sungairaya
# Processing Record 19 of Set 12 | dauphin
# Processing Record 20 of Set 12 | northam
# Processing Record 21 of Set 12 | kendari
# Processing Record 22 of Set 12 | constitucion
# Processing Record 23 of Set 12 | tanete
# Processing Record 24 of Set 12 | pulandian
# Processing Record 25 of Set 12 | berlevag
# Processing Record 26 of Set 12 | bollnas
# Processing Record 27 of Set 12 | mwingi
# Processing Record 28 of Set 12 | hibbing
# Processing Record 29 of Set 12 | castelldefels
# Processing Record 30 of Set 12 | springfield
# Processing Record 31 of Set 12 | kuruman
# Processing Record 32 of Set 12 | san joaquin
# Processing Record 33 of Set 12 | cap malheureux
# Processing Record 34 of Set 12 | tabou
# Processing Record 35 of Set 12 | ouesso
# Processing Record 36 of Set 12 | rodrigues alves
# Processing Record 37 of Set 12 | mareeba
# Processing Record 38 of Set 12 | kjollefjord
# Processing Record 39 of Set 12 | mlonggo
# Processing Record 40 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 12 | gimli
# Processing Record 42 of Set 12 | praia da vitoria
# Processing Record 43 of Set 12 | polson
# Processing Record 44 of Set 12 | cotonou
# Processing Record 45 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 12 | redlands
# Processing Record 47 of Set 12 | miranda
# Processing Record 48 of Set 12 | baturaja
# Processing Record 49 of Set 12 | balad
# Processing Record 50 of Set 12 | feijo
# Processing Record 1 of Set 13 | fritzlar
# Processing Record 2 of Set 13 | talcahuano
# Processing Record 3 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 13 | navolato
# Processing Record 5 of Set 13 | hudson bay
# Processing Record 6 of Set 13 | necochea
# Processing Record 7 of Set 13 | antalaha
# Processing Record 8 of Set 13 | kenora
# Processing Record 9 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 13 | honavar
# Processing Record 11 of Set 13 | denpasar
# Processing Record 12 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 13 of Set 13 | palmer
# Processing Record 14 of Set 13 | patacamaya
# Processing Record 15 of Set 13 | tessalit
# Processing Record 16 of Set 13 | alofi
# Processing Record 17 of Set 13 | sandakan
# Processing Record 18 of Set 13 | moron
# Processing Record 19 of Set 13 | grand-santi
# Processing Record 20 of Set 13 | mandiana
# Processing Record 21 of Set 13 | sobolevo
# Processing Record 22 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 13 | yatou
# Processing Record 24 of Set 13 | sanlucar la mayor
# Processing Record 25 of Set 13 | bilibino
# Processing Record 26 of Set 13 | nizhnyaya tavda
# Processing Record 27 of Set 13 | goure
# Processing Record 28 of Set 13 | burica
# City not found. Skipping...
# Processing Record 29 of Set 13 | son la
# Processing Record 30 of Set 13 | sam chuk
# Processing Record 31 of Set 13 | wexford
# Processing Record 32 of Set 13 | altamont
# Processing Record 33 of Set 13 | pontianak
# Processing Record 34 of Set 13 | sidi ali
# Processing Record 35 of Set 13 | concordia
# Processing Record 36 of Set 13 | zlotoryja
# Processing Record 37 of Set 13 | lichuan
# Processing Record 38 of Set 13 | tonj
# Processing Record 39 of Set 13 | bati
# Processing Record 40 of Set 13 | odweyne
# Processing Record 41 of Set 13 | kudat
# Processing Record 42 of Set 13 | grants
# Processing Record 43 of Set 13 | ambikapur
# Processing Record 44 of Set 13 | tual
# Processing Record 45 of Set 13 | kyshtovka
# Processing Record 46 of Set 13 | mormugao
# Processing Record 47 of Set 13 | rudnichnyy
# Processing Record 48 of Set 13 | ust-maya
# Processing Record 49 of Set 13 | dir
# Processing Record 50 of Set 13 | peniche
# Processing Record 1 of Set 14 | vestmanna
# Processing Record 2 of Set 14 | capari
# Processing Record 3 of Set 14 | rapid valley
# Processing Record 4 of Set 14 | tomatlan
# Processing Record 5 of Set 14 | knysna
# Processing Record 6 of Set 14 | fairbanks
# Processing Record 7 of Set 14 | oussouye
# Processing Record 8 of Set 14 | petaluma
# Processing Record 9 of Set 14 | saint-pierre
# Processing Record 10 of Set 14 | princeton
# Processing Record 11 of Set 14 | sinegorye
# Processing Record 12 of Set 14 | mezhdurechensk
# Processing Record 13 of Set 14 | baft
# Processing Record 14 of Set 14 | katobu
# Processing Record 15 of Set 14 | mongagua
# Processing Record 16 of Set 14 | manyana
# Processing Record 17 of Set 14 | gazli
# Processing Record 18 of Set 14 | tahe
# Processing Record 19 of Set 14 | mercedes
# Processing Record 20 of Set 14 | ciudad bolivar
# Processing Record 21 of Set 14 | butajira
# Processing Record 22 of Set 14 | carutapera
# Processing Record 23 of Set 14 | joao pinheiro
# Processing Record 24 of Set 14 | richards bay
# Processing Record 25 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 14 | alaca
# Processing Record 27 of Set 14 | alexandria
# Processing Record 28 of Set 14 | sakaiminato
# Processing Record 29 of Set 14 | barabai
# Processing Record 30 of Set 14 | los llanos de aridane
# Processing Record 31 of Set 14 | sisimiut
# Processing Record 32 of Set 14 | saint-augustin
# Processing Record 33 of Set 14 | deshnok
# Processing Record 34 of Set 14 | gijon
# Processing Record 35 of Set 14 | sao gabriel da cachoeira
# Processing Record 36 of Set 14 | gorin
# Processing Record 37 of Set 14 | abu samrah
# Processing Record 38 of Set 14 | aswan
# Processing Record 39 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 40 of Set 14 | koutsouras
# Processing Record 41 of Set 14 | wajid
# Processing Record 42 of Set 14 | marjamaa
# Processing Record 43 of Set 14 | harper
# Processing Record 44 of Set 14 | miraflores
# Processing Record 45 of Set 14 | jimma
# Processing Record 46 of Set 14 | husavik
# Processing Record 47 of Set 14 | san andres
# Processing Record 48 of Set 14 | la palma
# Processing Record 49 of Set 14 | luanda
# Processing Record 50 of Set 14 | shetpe
# Processing Record 1 of Set 15 | hopewell
# Processing Record 2 of Set 15 | naples
# Processing Record 3 of Set 15 | new castle
# Processing Record 4 of Set 15 | mizan teferi
# Processing Record 5 of Set 15 | viet tri
# Processing Record 6 of Set 15 | morant bay
# Processing Record 7 of Set 15 | portel
# Processing Record 8 of Set 15 | mildura
# Processing Record 9 of Set 15 | ixtapa
# Processing Record 10 of Set 15 | nuuk
# Processing Record 11 of Set 15 | pentecoste
# Processing Record 12 of Set 15 | puerto leguizamo
# Processing Record 13 of Set 15 | ko samui
# Processing Record 14 of Set 15 | luziania
# Processing Record 15 of Set 15 | onguday
# Processing Record 16 of Set 15 | talavera de la reina
# Processing Record 17 of Set 15 | nampa
# Processing Record 18 of Set 15 | likhovskoy
# Processing Record 19 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 20 of Set 15 | golden gate
# Processing Record 21 of Set 15 | ilheus
# Processing Record 22 of Set 15 | dori
# Processing Record 23 of Set 15 | kharsawan
# Processing Record 24 of Set 15 | villa del rosario
# Processing Record 25 of Set 15 | nevesinje
# Processing Record 26 of Set 15 | san antonio
# Processing Record 27 of Set 15 | yumen
# Processing Record 28 of Set 15 | sunagawa
# Processing Record 29 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 30 of Set 15 | zverinogolovskoye
# Processing Record 31 of Set 15 | watertown
# Processing Record 32 of Set 15 | changchun
# Processing Record 33 of Set 15 | chicla
# Processing Record 34 of Set 15 | hamilton
# Processing Record 35 of Set 15 | mackenzie
# Processing Record 36 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 15 | sibut
# Processing Record 38 of Set 15 | calama
# Processing Record 39 of Set 15 | prince rupert
# Processing Record 40 of Set 15 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 685

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk      AU -42.7826  147.0587     53.74        80          79
# 1  Vestmannaeyjar      IS  63.4427  -20.2734     54.59        47           0
# 2          Albany      US  42.6001  -73.9662     64.81        82         100
# 3      Pidhorodna      UA  48.1070   30.8895     57.99        44           3
# 4        Belmonte      BR -15.8631  -38.8828     84.20        66          33
# 5           Bluff      NZ -46.6000  168.3333     45.81        84         100
# 6           Buala      SB  -8.1450  159.5921     79.11        84          17
# 7  Ribeira Grande      PT  38.5167  -28.7000     75.60        83          40
# 8          Hasaki      JP  35.7333  140.8333     63.00        80           0
# 9         Kahului      US  20.8947 -156.4700     77.85        83          75
#
#    Wind Speed Current Description
# 0        0.92       broken clouds
# 1        3.44           clear sky
# 2        2.42          light rain
# 3        7.16           clear sky
# 4       13.33    scattered clouds
# 5       18.54       moderate rain
# 6        3.18          few clouds
# 7       11.50    scattered clouds
# 8       10.25           clear sky
# 9        0.00       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
